# %% [markdown]
# <a href="https://colab.research.google.com/github/praisyprincy005/COGNIFYZ-PROJECTS-Harshica/blob/main4/TASK_3_COGNIFYZ_PROJECT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import os
os.environ['KAGGLE_CONFIG_DIR']='/content/Data_set 2 - Copy.csv'

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/Data_set 2 - Copy.csv')
df
# Out:
#     gender  age Investment_Avenues  Mutual_Funds  Equity_Market  Debentures  \
# 0   Female   34                Yes             1              2           5
# 1   Female   23                Yes             4              3           2
# 2     Male   30                Yes             3              6           4
# 3     Male   22                Yes             2              1           3
# 4   Female   24                 No             2              1           3
# 5   Female   24                 No             7              5           4
# 6   Female   27                Yes             3              6           4
# 7     Male   21                Yes             2              3           7
# 8     Male   35                Yes             2              4           7
# 9     Male   31                Yes             1              3           7
# 10  Female   35                Yes             2              4           7
# ...

# %%
numerical_columns = df.select_dtypes(include=[np.number]).columns

# %%
for column in numerical_columns:
    mean_value = df[column].mean()
    median_value = df[column].median()
    std_value = df[column].std()

    print(f"Column: {column}")
    print(f"Mean: {mean_value}")
    print(f"Median: {median_value}")
    print(f"Standard Deviation: {std_value}\n")
# Out:
# Column: age
# Mean: 27.8
# Median: 27.0
# Standard Deviation: 3.560466693696639
#
# Column: Mutual_Funds
# Mean: 2.55
# Median: 2.0
# Standard Deviation: 1.1972189997378648
#
# Column: Equity_Market
# Mean: 3.475
# Median: 4.0
# Standard Deviation: 1.1319939294935535
#
# Column: Debentures
# Mean: 5.75
# Median: 6.5
# Standard Deviation: 1.6756169931378433
#
# Column: Government_Bonds
# Mean: 4.65
# Median: 5.0
# Standard Deviation: 1.369072304284538
#
# Column: Fixed_Deposits
# Mean: 3.575
# Median: 3.5
# Standard Deviation: 1.795828499606797
#
# Column: PPF
# Mean: 2.025
# Median: 1.0
# Standard Deviation: 1.6090688500193409
#
# Column: Gold
# Mean: 5.975
# Median: 6.0
# Standard Deviation: 1.1432634351063984
